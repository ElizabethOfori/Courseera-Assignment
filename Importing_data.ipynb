# %% [markdown]
# <a href="https://colab.research.google.com/github/ElizabethOfori/Courseera-Assignment/blob/main/Importing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Download cities.csv in C7W1 Activity folder
import pandas as pd
import numpy as np
df_cities = pd.read_csv('/content/Activity/cities.csv')
df_cities.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"
# 0        "Youngstown"       OH
# 1           "Yankton"       SD
# 2            "Yakima"       WA
# 3         "Worcester"       MA
# 4   "Wisconsin Dells"       WI

# %%
#Add a column to the dataframe
df_cities['NewColumn'] = 0
df_cities.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"  NewColumn
# 0        "Youngstown"       OH          0
# 1           "Yankton"       SD          0
# 2            "Yakima"       WA          0
# 3         "Worcester"       MA          0
# 4   "Wisconsin Dells"       WI          0

# %%
#Perform describe and info on dataframe
df_cities.describe()
df_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LatD       128 non-null    int64
#  1    "LatM"    128 non-null    int64
#  2    "LatS"    128 non-null    int64
#  3    "NS"      128 non-null    object
#  4    "LonD"    128 non-null    int64
#  5    "LonM"    128 non-null    int64
#  6    "LonS"    128 non-null    int64
#  7    "EW"      128 non-null    object
#  8    "City"    128 non-null    object
#  9    "State"   128 non-null    object
#  10  NewColumn  128 non-null    int64
# dtypes: int64(7), object(4)
# memory usage: 11.1+ KB

# %%
#Export and save this data as cities1.csv
df_cities.to_csv('/content/Activity/cities1.csv')

# %%
#Import xlsx in a dataframe\
df_xlsx = pd.read_excel('/content/Activity/CarSalesByModelStart.xlsx')
df_xlsx.head()
# Out:
#    Year    Month                Date      Model  Dealer ID  Quantity Sold  \
# 0  2018  January 2018-01-01 23:00:00   Beaufort       1222             10
# 1  2018  January 2018-01-01 23:00:00     Salish       1222             13
# 2  2018  January 2018-01-01 23:00:00   Labrador       1222             16
# 3  2018  January 2018-01-01 23:00:00  Champlain       1222              3
# 4  2018  January 2018-01-01 23:00:00     Hudson       1222             22
#
#     Profit
# 0  15000.0
# 1  39650.0
# 2  12800.0
# 3   6900.0
# 4  11000.0

# %%
#Add a column to the dataframe
df_xlsx['NewColumn'] = 0
df_xlsx.head()
# Out:
#    Year    Month                Date      Model  Dealer ID  Quantity Sold  \
# 0  2018  January 2018-01-01 23:00:00   Beaufort       1222             10
# 1  2018  January 2018-01-01 23:00:00     Salish       1222             13
# 2  2018  January 2018-01-01 23:00:00   Labrador       1222             16
# 3  2018  January 2018-01-01 23:00:00  Champlain       1222              3
# 4  2018  January 2018-01-01 23:00:00     Hudson       1222             22
#
#     Profit  NewColumn
# 0  15000.0          0
# 1  39650.0          0
# 2  12800.0          0
# 3   6900.0          0
# 4  11000.0          0

# %%
#Perform describe and info on dataframe
df_xlsx.describe()
df_xlsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           1200 non-null   int64
#  1   Month          1200 non-null   object
#  2   Date           1200 non-null   datetime64[ns]
#  3   Model          1200 non-null   object
#  4   Dealer ID      1200 non-null   int64
#  5   Quantity Sold  1200 non-null   int64
#  6   Profit         1200 non-null   float64
#  7   NewColumn      1200 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 75.1+ KB

# %%
#Export and save this data as CarSalesByModelStart1.xlsx
df_xlsx.to_excel('/content/Activity/CarSalesByModelStart1.xlsx')

# %%
#Import the Json in dataframe
df = pd.read_json('/content/Activity/Jay (1).json')
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#Add a column to the dataframe
df['NewColumn'] = 0
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories  NewColumn
# 0        60    110       130     409.1          0
# 1        60    117       145     479.0          0
# 2        60    103       135     340.0          0
# 3        45    109       175     282.4          0
# 4        45    117       148     406.0          0

# %%
#Perform describe and info on dataframe
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 169 entries, 0 to 168
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Duration   169 non-null    int64
#  1   Pulse      169 non-null    int64
#  2   Maxpulse   169 non-null    int64
#  3   Calories   164 non-null    float64
#  4   NewColumn  169 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 7.9 KB

# %%
#Export and save this data as Jay1.json
df.to_json('/content/Activity/Jay1.json')
